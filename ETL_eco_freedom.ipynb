# %% [markdown]
# # ECONOMIC FREEDOM DATA 2019

# %%
# DEPENDENCIES AND SETUP

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ####  EXTRACTING DATA FROM KAGGLE

# %% [markdown]
#    ######  Data taken from url  https://www.kaggle.com/lewisduncan93/the-economic-freedom-index

# %%
# Specyfying CSV path
eco_index = "./mini_project_economic_freedom.csv"

# %%
# Reading csv file and creating dataframe

eco_df = pd.read_csv(eco_index)
eco_df.head()
# Out:
#    CountryID Country Name      WEBNAME                        Region  \
# 0          1  Afghanistan  Afghanistan                  Asia-Pacific
# 1          2      Albania      Albania                        Europe
# 2          3      Algeria      Algeria  Middle East and North Africa
# 3          4       Angola       Angola            Sub-Saharan Africa
# 4          5    Argentina    Argentina                      Americas
#
#    World Rank  Region Rank  2019 Score  Property Rights  \
# 0       152.0         39.0        51.5             19.6
# 1        52.0         27.0        66.5             54.8
# 2       171.0         14.0        46.2             31.6
# 3       156.0         33.0        50.6             35.9
# 4       148.0         26.0        52.2             47.8
#
#    Judical Effectiveness  Government Integrity  ...      Country  \
# 0                   29.6                  25.2  ...  Afghanistan
# 1                   30.6                  40.4  ...      Albania
# ...

# %% [markdown]
# #####  TRANSFORM DATA

# %%
# Considering the columns needed

eco_index_new_df = eco_df[['CountryID', 'Country Name', 'Region', 'World Rank', 'Region Rank', '2019 Score', 'Labor Freedom', 'Population (Millions)', 'Unemployment (%)', 'Inflation (%)']].copy()
eco_index_new_df.head()
#eco_index_new_df
# Out:
#    CountryID Country Name                        Region  World Rank  \
# 0          1  Afghanistan                  Asia-Pacific       152.0
# 1          2      Albania                        Europe        52.0
# 2          3      Algeria  Middle East and North Africa       171.0
# 3          4       Angola            Sub-Saharan Africa       156.0
# 4          5    Argentina                      Americas       148.0
#
#    Region Rank  2019 Score  Labor Freedom Population (Millions)  \
# 0         39.0        51.5           60.4                  35.5
# 1         27.0        66.5           52.7                   2.9
# 2         14.0        46.2           49.9                  41.5
# 3         33.0        50.6           58.8                  28.2
# 4         26.0        52.2           46.9                  44.1
#
#   Unemployment (%)  Inflation (%)
# 0              8.8            5.0
# 1             13.9            2.0
# 2               10            5.6
# ...

# %%
# Deleteing unwanted rows by using dropna()

eco_df_clean = eco_index_new_df.dropna()
eco_df_clean.head()
#eco_df_clean
# Out:
#    CountryID Country Name                        Region  World Rank  \
# 0          1  Afghanistan                  Asia-Pacific       152.0
# 1          2      Albania                        Europe        52.0
# 2          3      Algeria  Middle East and North Africa       171.0
# 3          4       Angola            Sub-Saharan Africa       156.0
# 4          5    Argentina                      Americas       148.0
#
#    Region Rank  2019 Score  Labor Freedom Population (Millions)  \
# 0         39.0        51.5           60.4                  35.5
# 1         27.0        66.5           52.7                   2.9
# 2         14.0        46.2           49.9                  41.5
# 3         33.0        50.6           58.8                  28.2
# 4         26.0        52.2           46.9                  44.1
#
#   Unemployment (%)  Inflation (%)
# 0              8.8            5.0
# 1             13.9            2.0
# 2               10            5.6
# ...

# %%
# sort the dataframe by column name "World Bank"

eco_df_clean_sorted = eco_df_clean.sort_values('World Rank')
eco_df_clean_sorted.head()
# Out:
#      CountryID Country Name        Region  World Rank  Region Rank  \
# 72          71    Hong Kong  Asia-Pacific         1.0          1.0
# 149        147    Singapore  Asia-Pacific         2.0          2.0
# 122        120  New Zealand  Asia-Pacific         3.0          3.0
# 160        158  Switzerland        Europe         4.0          1.0
# 6            7    Australia  Asia-Pacific         5.0          4.0
#
#      2019 Score  Labor Freedom Population (Millions) Unemployment (%)  \
# 72         90.2           89.2                   7.4              3.1
# 149        89.4           91.0                   5.6                2
# 122        84.4           86.7                   4.8              4.9
# 160        81.9           72.5                   8.4              4.8
# 6          80.9           84.1                  24.8              5.6
#
#      Inflation (%)
# 72             1.5
# 149            0.6
# 122            1.9
# 160            0.5
# 6              2.0

# %%
# Reseting the index 

eco_df_clean_reindex = eco_df_clean_sorted.reset_index(drop=True)
eco_df_clean_reindex.head()
#eco_df_clean_reindex
# Out:
#    CountryID Country Name        Region  World Rank  Region Rank  2019 Score  \
# 0         71    Hong Kong  Asia-Pacific         1.0          1.0        90.2
# 1        147    Singapore  Asia-Pacific         2.0          2.0        89.4
# 2        120  New Zealand  Asia-Pacific         3.0          3.0        84.4
# 3        158  Switzerland        Europe         4.0          1.0        81.9
# 4          7    Australia  Asia-Pacific         5.0          4.0        80.9
#
#    Labor Freedom Population (Millions) Unemployment (%)  Inflation (%)
# 0           89.2                   7.4              3.1            1.5
# 1           91.0                   5.6                2            0.6
# 2           86.7                   4.8              4.9            1.9
# 3           72.5                   8.4              4.8            0.5
# 4           84.1                  24.8              5.6            2.0

# %%
# Consider top 5 countries based on "World Rank"

Top_Five_Condition = eco_df_clean_reindex['World Rank'] < 6
Top_Five = eco_df_clean_reindex[Top_Five_Condition]
Top_Five
# Out:
#    CountryID Country Name        Region  World Rank  Region Rank  2019 Score  \
# 0         71    Hong Kong  Asia-Pacific         1.0          1.0        90.2
# 1        147    Singapore  Asia-Pacific         2.0          2.0        89.4
# 2        120  New Zealand  Asia-Pacific         3.0          3.0        84.4
# 3        158  Switzerland        Europe         4.0          1.0        81.9
# 4          7    Australia  Asia-Pacific         5.0          4.0        80.9
#
#    Labor Freedom Population (Millions) Unemployment (%)  Inflation (%)
# 0           89.2                   7.4              3.1            1.5
# 1           91.0                   5.6                2            0.6
# 2           86.7                   4.8              4.9            1.9
# 3           72.5                   8.4              4.8            0.5
# 4           84.1                  24.8              5.6            2.0

# %%
# Plotting the top Five countries economic freedom score of 2019

Top_Five_Eco = pd.pivot_table(Top_Five, index = 'Country Name', values = '2019 Score')
Top_Five_Eco.plot(kind = 'bar', color = "green", figsize=(10,6), fontsize = 15, rot=90)

#set title
plt.title('Top Five Countries - Economic Freedom Score 2019', fontsize = 15)
#set legend
plt.legend(bbox_to_anchor=(0, 1), loc='right', ncol=1, fontsize = 12)
#set yaxis label
plt.ylabel('Economic Freedom Score', fontsize = 15)
# set xaxis label
plt.xlabel('Countries', fontsize = 15)
# To save figure      
plt.savefig("Images/eco_top_five.png", bbox_inches="tight") 
# show figure
plt.show()

# %%
# Consider bottom 5 countries based on "World Rank"

Bottom_Five_Condition = eco_df_clean_reindex['World Rank'] > 174
Bottom_Five = eco_df_clean_reindex[Bottom_Five_Condition]
Bottom_Five
# Out:
#      CountryID        Country Name              Region  World Rank  \
# 169        183            Zimbabwe  Sub-Saharan Africa       175.0
# 170         38  Congo, Republic of  Sub-Saharan Africa       176.0
# 171         53             Eritrea  Sub-Saharan Africa       177.0
# 172         42                Cuba            Americas       178.0
# 173        179           Venezuela            Americas       179.0
#
#      Region Rank  2019 Score  Labor Freedom Population (Millions)  \
# 169         45.0        40.4           43.3                  14.9
# 170         46.0        39.7           35.8                   4.3
# 171         47.0        38.9           70.0                   5.9
# 172         31.0        27.8           20.0                  11.5
# 173         32.0        25.9           28.0                  31.4
#
#     Unemployment (%)  Inflation (%)
# 169                5            1.3
# 170               11            0.5
# 171              6.4            9.0
# ...

# %%
# Plotting the Bottom Five countries economic freedom score of 2019


Bottom_Five_Eco = pd.pivot_table(Bottom_Five, index = 'Country Name', values = '2019 Score')
Bottom_Five_Eco.plot(kind = 'bar', color = "coral", figsize=(10,6), fontsize = 15, rot=90)

#set title
plt.title('Bottom Five Countries - Economic Freedom Score 2019', fontsize = 15)
#set legend
plt.legend(bbox_to_anchor=(0, 1), loc='right', ncol=1, fontsize = 12)
#set yaxis label
plt.ylabel('Economic Freedom Score', fontsize = 15)
# set xaxis label
plt.xlabel('Countries', fontsize = 15)
# To save figure      
plt.savefig("Images/eco_bottom_five.png", bbox_inches="tight") 
# show figure
plt.show()

# %%
# sort by column "Region" and taking columns "Country Name","Region","2019 Score","Labor Freedom"

eco_df_labor_freedom = eco_df_clean_reindex.sort_values("Region")[["Country Name","Region","2019 Score","Labor Freedom"]]
eco_df_labor_freedom.head()
# Out:
#     Country Name    Region  2019 Score  Labor Freedom
# 173    Venezuela  Americas        25.9           28.0
# 103    Nicaragua  Americas        57.7           55.8
# 89      Honduras  Americas        60.2           32.0
# 172         Cuba  Americas        27.8           20.0
# 37   Saint Lucia  Americas        68.7           69.2

# %%
# Creating scatter plot based on 'Economic Freedom Score-2019','Labor Freedom' and "Region"

fig, ax = plt.subplots(figsize=(9,6))
#set margins
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
# set xaxis label
ax.set_xlabel('Labor Freedom', fontsize = 15)
# set yaxis label
ax.set_ylabel('Economic Freedom Score-2019', fontsize = 15)
# set title
ax.set_title('Economic Freedom Score-2019 Vs Labor Freedom', fontsize = 15)

# For loop is used  for ploting
# Do group by on dataframe "eco_df_labor_freedom" based on column "Region"
# loop through all groups one by one
for name, group in eco_df_labor_freedom.groupby('Region'):
    group.plot(x='Labor Freedom', y='2019 Score', ax=ax, marker='o',
               linestyle='', ms=10, label=name, fontsize = 15)

ax.legend(fontsize = 10)
# save figure
plt.savefig("Images/scatter_plot.png", bbox_inches="tight")
# show figure
plt.show()

# %% [markdown]
# ######  CREATING HTML TABLE FROM DATAFRAME "eco_df_clean_sorted"

# %%
# Creating html table from dataframe "eco_df_clean_sorted"

eco_df_clean_sorted.to_html('table_NEW.html', index=False)
